# %%
import pandas as pd
from IPython.display import HTML

# %%
cities = "Resources/citydataclean.csv"

# %%
city_df = pd.read_csv(cities)
city_df.head()
# Out:
#            City Country  City ID      Lat      Long  Max Temp  Humidity  \
# 0  Punta Arenas      CL  3874787 -53.1500  -70.9167     46.40        87
# 1        Gannan      CN  2037311  47.9147  123.5031     48.70        23
# 2        Hobart      AU  2163355 -42.8794  147.3294     50.00        66
# 3         Rundu     NaN  3353383 -17.9333   19.7667     84.65        17
# 4       Mataura      NZ  6201424 -46.1927  168.8643     43.00        92
#
#    Cloudiness  Wind Speed        Date
# 0           0       10.36  1619272607
# 1           0        5.12  1619272608
# 2          40        6.91  1619272609
# 3           0        3.33  1619272609
# 4          14        5.01  1619272610

# %%
HTML(city_df.to_html(classes='table table-responsive'))
# Out:
# <table border="1" class="dataframe table table-responsive">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>City ID</th>
#       <th>Lat</th>
#       <th>Long</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Punta Arenas</td>
#       <td>CL</td>
#       <td>3874787</td>
#       <td>-53.1500</td>
#       <td>-70.9167</td>
#       <td>46.40</td>
#       <td>87</td>
#       <td>0</td>
#       <td>10.36</td>
#       <td>1619272607</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Gannan</td>
#       <td>CN</td>
#       <td>2037311</td>
#       <td>47.9147</td>
#       <td>123.5031</td>
#       <td>48.70</td>
#       <td>23</td>
#       <td>0</td>
#       <td>5.12</td>
#       <td>1619272608</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
city_df.to_csv('citydata.csv', index=False)

# %%
html = city_df.to_html(classes='table table-responsive')
  
# write html to file
text_file = open("index_data.html", "w", encoding="utf-8")
text_file.write(html)
text_file.close()
